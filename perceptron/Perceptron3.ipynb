# %%
import numpy as np

# entradas = np.array([[0,0], [0,1], [1,0], [1,1]])
# saidas = np.array([0,0,0,1])
entradas = np.array([[0,0], [0,1], [1,0], [1,1]])
saidas = np.array([0,1,1,1])
pesos = np.array([0.0, 0.0])
taxaAprendizagem = 0.1

def stepFunction(soma):
    return 1 if soma >= 1 else 0

def calculaSaida(registro):
    s = registro.dot(pesos)
    return stepFunction(s)

def treinar():
    erroTotal = 1
    while(erroTotal != 0):
        erroTotal = 0
        for i in range(len(saidas)):
            saidaCalculada = calculaSaida(np.asarray(entradas[i]))
            erro = abs(saidas[i] - saidaCalculada)
            erroTotal += erro
            for j in range(len(pesos)):
                pesos[j] = pesos[j] + (taxaAprendizagem * entradas[i][j] * erro)
                print(f'Pesos atualizados: {str(pesos[j])}')
        print(f'Total de erros: {erroTotal}')

treinar()
# Out:
# Pesos atualizados: 0.0
# Pesos atualizados: 0.0
# Pesos atualizados: 0.0
# Pesos atualizados: 0.1
# Pesos atualizados: 0.1
# Pesos atualizados: 0.1
# Pesos atualizados: 0.2
# Pesos atualizados: 0.2
# Total de erros: 3
# Pesos atualizados: 0.2
# Pesos atualizados: 0.2
# Pesos atualizados: 0.2
# Pesos atualizados: 0.30000000000000004
# Pesos atualizados: 0.30000000000000004
# Pesos atualizados: 0.30000000000000004
# Pesos atualizados: 0.4
# Pesos atualizados: 0.4
# Total de erros: 3
# Pesos atualizados: 0.4
# Pesos atualizados: 0.4
# Pesos atualizados: 0.4
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Total de erros: 2
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Pesos atualizados: 0.5
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Total de erros: 2
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Pesos atualizados: 0.6
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Total de erros: 2
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Total de erros: 2
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.7999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Total de erros: 2
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.8999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Total de erros: 2
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 0.9999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Total de erros: 2
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Pesos atualizados: 1.0999999999999999
# Total de erros: 0
